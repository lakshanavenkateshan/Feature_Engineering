# %% [markdown]
# # LABEL ENCODING ORDINAL ENCODING (DATETIME)

# %%
import pandas as pd
import datetime

# %%
#create a variable with dates and from that extract the weekday
#i create a list of dates with 20 difference from today
#and then transform it into a dataframe
df_base=datetime.datetime.today()
df_date_list=[df_base - datetime.timedelta(days=x) for x in range(0,20)]
df=pd.DataFrame(df_date_list)
df.columns=['day']
df
# Out:
#                           day
# 0  2025-08-17 04:07:09.380641
# 1  2025-08-16 04:07:09.380641
# 2  2025-08-15 04:07:09.380641
# 3  2025-08-14 04:07:09.380641
# 4  2025-08-13 04:07:09.380641
# 5  2025-08-12 04:07:09.380641
# 6  2025-08-11 04:07:09.380641
# 7  2025-08-10 04:07:09.380641
# 8  2025-08-09 04:07:09.380641
# 9  2025-08-08 04:07:09.380641
# 10 2025-08-07 04:07:09.380641
# 11 2025-08-06 04:07:09.380641
# 12 2025-08-05 04:07:09.380641
# 13 2025-08-04 04:07:09.380641
# 14 2025-08-03 04:07:09.380641
# 15 2025-08-02 04:07:09.380641
# 16 2025-08-01 04:07:09.380641
# 17 2025-07-31 04:07:09.380641
# 18 2025-07-30 04:07:09.380641
# 19 2025-07-29 04:07:09.380641

# %%
#extract the week day name
df['day_of_week']=df['day'].dt.day_name()
df.head()
# Out:
#                          day day_of_week
# 0 2025-08-17 04:07:09.380641      Sunday
# 1 2025-08-16 04:07:09.380641    Saturday
# 2 2025-08-15 04:07:09.380641      Friday
# 3 2025-08-14 04:07:09.380641    Thursday
# 4 2025-08-13 04:07:09.380641   Wednesday

# %%
#engineer categorical variable by ordinal number placement
weekday_map={'Monday':1,
             'Tuesday':2,
             'Wednesday':3,
             'Thursday':4,
             'Friday':5,
             'Saturday':6,
             'Sunday':7
}
df['day_ordinal']=df.day_of_week.map(weekday_map)
df.head(10)
# Out:
#                          day day_of_week  day_ordinal
# 0 2025-08-17 04:07:09.380641      Sunday            7
# 1 2025-08-16 04:07:09.380641    Saturday            6
# 2 2025-08-15 04:07:09.380641      Friday            5
# 3 2025-08-14 04:07:09.380641    Thursday            4
# 4 2025-08-13 04:07:09.380641   Wednesday            3
# 5 2025-08-12 04:07:09.380641     Tuesday            2
# 6 2025-08-11 04:07:09.380641      Monday            1
# 7 2025-08-10 04:07:09.380641      Sunday            7
# 8 2025-08-09 04:07:09.380641    Saturday            6
# 9 2025-08-08 04:07:09.380641      Friday            5
